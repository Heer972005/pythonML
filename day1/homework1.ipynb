# %%
name="Heer"
sub1=90
sub2=99
sub3=94
total=sub1+sub2+sub3
avg=total/3
print("Name:",name)
print("Total marks:",total)
print("Average marks:",avg)
# Out:
# Name: Heer
# Total marks: 283
# Average marks: 94.33333333333333
