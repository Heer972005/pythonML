# %%
name="Heer"
age=20
city="Rajkot"
smartphone=True
print("Name:",name)
print("Age:",age)
print("City:",city)
print("Owns a smartphone:",smartphone)
# Out:
# Name: Heer
# Age: 20
# City: Rajkot
# Owns a smartphone: True

# %%
length=5
width=3
area=length*width
print("Area of the rectangle:",area)
# Out:
# Area of the rectangle: 15

# %%
OS=90
DBMS=99
total=OS+DBMS
avg=total/2
print("Total marks:",total)
print("Average marks:",avg)
# Out:
# Total marks: 189
# Average marks: 94.5

# %%
name="Heer"
age=20
city="Rajkot"
smartphone=True
print("Name:",type(name))
print("Age:",type(age))
print("City:",type(city))
print("Owns a smartphone:",type(smartphone))
# Out:
# Name: <class 'str'>
# Age: <class 'int'>
# City: <class 'str'>
# Owns a smartphone: <class 'bool'>

# %%
num=255
print("Integer:",num)
print("Type of num:",type(num))
numStr=str(num)
print("String:",numStr)
print("Type of numStr:",type(numStr))

print("\n")
numFromString=int(numStr)
print("Integer from string:",type(numFromString))
# Out:
# Integer: 255
# Type of num: <class 'int'>
# String: 255
# Type of numStr: <class 'str'>
#
#
# Integer from string: <class 'int'>
