# %%
#1
# The dataset already contains 20 numeric columns, and applying degree=3 
# polynomial features to all columns will create more than 1700 features.
#Feature explosion (curse of dimensionality)
#Many generated features will be noise

# %%
# 2
# Enroll_Month will marked as integers (1–12).
# KNN is a distance-based model, so it interprets:
# January = 1
# December = 12
# as being very far apart, although they are adjacent months.
# Consequence
# Distance calculations become incorrect and seasonal patterns are not captured properly.

# %%
# 3
# The correlation matrix is computed using both training and test data.

# Consequence
# This causes data leakage.
# Information from the test set influences feature selection, producing overly optimistic performance estimates.
