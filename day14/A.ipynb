# %%
#1
feature creation---new features/colunms are added
feature selection---we select/filter the desried the columns/features for training
we need both
feture selection mitigates the curse of domentionality
and creation hekpps in finding/creating meaingful patterns


#2
Total_Expenses = Rent + Food + Transport
Ratio Feature:
Savings_Rate = Savings / Income
Interaction Feature:
Advertising_Budget × Seasonality_Index

#3
These variables are cyclic. For example, December and January are 
consecutive months, but their integer values (12 and 1) appear far apart numerically. 
Sine and cosine encoding preserves this circular relationship which helps in identifying the patterns correctly

#4
As the number of features grows, the volume of the feature space/dimesion too grow.
Irrelevant features add noise, slow down training,
increase memory usage, and can actually reduce model accuracy by diluting the signal from informative features.
This phenomenon is known as the curse of dimensionality.

#5
Filter methods score each feature independently
using a statistical test (correlation, chi-squared, mutual information) without involving a model — they are fast
 
Wrapper methods (such as RFE) iteratively train a model and use its performance to decide which
features to keep — they are more accurate but computationally expensive. 

Embedded methods perform selection as part of model training itself (LASSO regularisation, tree-based feature 
importances) — they strike a balance between speed and accuracy.

#6
Feature selection must be learned only from the training data to prevent data
leakage. Using the full dataset (training + test) allows information from the test 
set to influence the training process, leading to overly optimistic performance estimates.

#7
The chi-square statistic assumes that feature values represent non-negative frequencies or counts.
Negative values violate this assumption and can produce invalid scores.
# Out:
#   Cell In[1], line 14
#     Advertising_Budget × Seasonality_Index
#                        ^
# SyntaxError: invalid character '×' (U+00D7)
